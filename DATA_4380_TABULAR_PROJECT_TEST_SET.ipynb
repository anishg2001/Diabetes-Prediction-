# %% [markdown]
# # DATA RAN ON THE TEST SET

# %%
#Importing libaries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn import svm
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import roc_curve, roc_auc_score, accuracy_score

# %%
from google.colab import files

uploaded = files.upload()

for filename, content in uploaded.items():
    print(f"Uploaded file: {filename}, size: {len(content)} bytes")
# Out:
#      <input type="file" id="files-135d62db-fb70-47af-b150-8836df6f09bf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-135d62db-fb70-47af-b150-8836df6f09bf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('test[1].csv')
df.head()
# Out:
#    id  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0   1            0      145              0              0        0  44.2
# 1   2            2      100             68             25       71  38.5
# 2   3            0       95             85             25       36  37.4
# 3   4            0      117             66             31      188  30.8
# 4   5            6      114             88              0        0  27.8
#
#    DiabetesPedigreeFunction  Age
# 0                     0.630   31
# 1                     0.324   26
# 2                     0.247   24
# 3                     0.493   22
# 4                     0.247   66

# %%
missing_values=df.isnull().sum()
missing_values
# Out:
# id                          0
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# dtype: int64

# %%
X = df.drop(columns=['id'])  # Drop 'id' and 'label' columns
y = df['id']

# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %% [markdown]
# #Metrics

# %%
from sklearn.metrics import classification_report

# Inspect class distribution
print("Class distribution in training data:")
print(y_train.value_counts())

# Print some predictions
print("Sample predictions:")
print(y_pred[:10])

# Calculate metrics
print("Classification Report:")
print(classification_report(y_test, y_pred))

# %% [markdown]
# **Classification Report:**
#
#
# - **Precision:** 0.76
#   Of all the instances predicted as class 0, 78% are actually class 0.
# - **Recall:** 0.64
#   Of all the actual class 0 instances, 62% were correctly identified.
# - **F1-Score:** 0..71
#   This is the harmonic mean of precision and recall, balancing both.
#
#
# - **Precision:** 0.72
#   Of all the instances predicted as class 1, 84% are actually class 1.
# - **Recall:** 0.47
#   Of all the actual class 1 instances, 54% were correctly identified.
# - **F1-Score:** 0.69
#   This balances precision and recall for class 1.
